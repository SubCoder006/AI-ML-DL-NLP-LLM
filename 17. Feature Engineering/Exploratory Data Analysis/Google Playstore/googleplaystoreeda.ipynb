# %% [markdown]
# ## 📊 Google Play Store Dataset - EDA Notes
#
# ### 📁 Dataset Overview
# - Contains details of apps on Google Play Store
# - Key features:
#   - App, Category, Rating, Reviews
#   - Size, Installs, Type (Free/Paid)
#   - Price, Content Rating, Genres
#   - Last Updated, Current Ver, Android Ver
#
# ---
#
# ### 🧹 Data Cleaning
# - Handle missing values:
#   - `Rating` → fill with median
#   - `Type`, `Content Rating` → mode
# - Remove duplicates (based on App name)
# - Convert data types:
#   - `Reviews` → int
#   - `Installs` → remove `+`, `,` → int
#   - `Price` → remove `$` → float
# - Convert `Size`:
#   - M → MB, k → MB
#
# ---
#
# ### 🔍 Univariate Analysis
# - **Rating**
#   - Mostly between 4.0 – 4.5
# - **Category**
#   - Most apps: FAMILY, GAME, TOOLS
# - **Type**
#   - Majority apps are Free
# - **Content Rating**
#   - Mostly "Everyone"
#
# ---
#
# ### 📊 Bivariate Analysis
# - **Rating vs Reviews**
#   - Higher reviews → slightly higher rating (not strong)
# - **Category vs Installs**
#   - GAME & COMMUNICATION → highest installs
# - **Free vs Paid**
#   - Free apps dominate installs
#
# ---
#
# ### 📈 Key Visualizations
# - Histogram → Ratings distribution
# - Countplot → Categories
# - Boxplot → Rating vs Category
# - Scatterplot → Reviews vs Rating
#
# ---
#
# ### ⚠️ Outliers
# - Extremely high reviews (top apps like WhatsApp, Facebook)
# - Some ratings = 19 (invalid → removed)
#
# ---
#
# ### 💡 Insights
# - Free apps drive most downloads
# - Popular categories: GAME, FAMILY
# - Ratings are generally high → positive bias
# - Paid apps are very few and less installed
#
# ---
#
# ### 🚀 Feature Engineering
# - Create:
#   - `Installs_bin` (Low, Medium, High)
#   - `Price_category` (Free, Low, Premium)
# - Convert date to datetime → extract year/month
#
# ---
#
# ### 🧠 Conclusion
# - Dataset is skewed toward free apps
# - Ratings are not highly discriminative
# - Installs & Reviews are strong indicators of popularity

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv('googleplaystore.csv')
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# ## **Insights and Observation**
# > The data has `missing values`.

# %%
df.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size  Installs  Type Price Content Rating  \
# 0     159  19M   10,000+  Free     0       Everyone
# 1     967  14M  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
df[~df['Reviews'].str.isnumeric()]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df_copy = df.copy()
df_copy = df_copy.drop(10472)

# %%
df_copy.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
df_copy[-df_copy['Reviews'].str.isnumeric()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
## convert reviews datatype to int64
df_copy['Reviews']=df_copy['Reviews'].astype(int)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            10840 non-null  object
#  5   Installs        10840 non-null  object
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.2+ MB

# %%
df_copy['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
#        '5.1M', '61M', '66M', '79k', '8.4M', '118k', '44M', '695k', '1.6M',
#        '6.2M', '18k', '53M', '1.4M', '3.0M', '5.8M', '3.8M', '9.6M',
#        '45M', '63M', '49M', '77M', '4.4M', '4.8M', '70M', '6.9M', '9.3M',
#        '10.0M', '8.1M', '36M', '84M', '97M', '2.0M', '1.9M', '1.8M',
#        '5.3M', '47M', '556k', '526k', '76M', '7.6M', '59M', '9.7M', '78M',
#        '72M', '43M', '7.7M', '6.3M', '334k', '34M', '93M', '65M', '79M',
#        '100M', '58M', '50M', '68M', '64M', '67M', '60M', '94M', '232k',
#        '99M', '624k', '95M', '8.5k', '41k', '292k', '11k', '80M', '1.7M',
#        '74M', '62M', '69M', '75M', '98M', '85M', '82M', '96M', '87M',
#        '71M', '86M', '91M', '81M', '92M', '83M', '88M', '704k', '862k',
#        '899k', '378k', '266k', '375k', '1.3M', '975k', '980k', '4.1M',
#        '89M', '696k', '544k', '525k', '920k', '779k', '853k', '720k',
#        '713k', '772k', '318k', '58k', '241k', '196k', '857k', '51k',
#        '953k', '865k', '251k', '930k', '540k', '313k', '746k', '203k',
#        '26k', '314k', '239k', '371k', '220k', '730k', '756k', '91k',
#        '293k', '17k', '74k', '14k', '317k', '78k', '924k', '902k', '818k',
#        '81k', '939k', '169k', '45k', '475k', '965k', '90M', '545k', '61k',
#        '283k', '655k', '714k', '93k', '872k', '121k', '322k', '1.0M',
#        '976k', '172k', '238k', '549k', '206k', '954k', '444k', '717k',
#        '210k', '609k', '308k', '705k', '306k', '904k', '473k', '175k',
#        '350k', '383k', '454k', '421k', '70k', '812k', '442k', '842k',
#        '417k', '412k', '459k', '478k', '335k', '782k', '721k', '430k',
#        '429k', '192k', '200k', '460k', '728k', '496k', '816k', '414k',
#        '506k', '887k', '613k', '243k', '569k', '778k', '683k', '592k',
#        '319k', '186k', '840k', '647k', '191k', '373k', '437k', '598k',
#        '716k', '585k', '982k', '222k', '219k', '55k', '948k', '323k',
#        '691k', '511k', '951k', '963k', '25k', '554k', '351k', '27k',
#        '82k', '208k', '913k', '514k', '551k', '29k', '103k', '898k',
#        '743k', '116k', '153k', '209k', '353k', '499k', '173k', '597k',
#        '809k', '122k', '411k', '400k', '801k', '787k', '237k', '50k',
#        '643k', '986k', '97k', '516k', '837k', '780k', '961k', '269k',
#        '20k', '498k', '600k', '749k', '642k', '881k', '72k', '656k',
#        '601k', '221k', '228k', '108k', '940k', '176k', '33k', '663k',
#        '34k', '942k', '259k', '164k', '458k', '245k', '629k', '28k',
#        '288k', '775k', '785k', '636k', '916k', '994k', '309k', '485k',
#        '914k', '903k', '608k', '500k', '54k', '562k', '847k', '957k',
#        '688k', '811k', '270k', '48k', '329k', '523k', '921k', '874k',
#        '981k', '784k', '280k', '24k', '518k', '754k', '892k', '154k',
#        '860k', '364k', '387k', '626k', '161k', '879k', '39k', '970k',
#        '170k', '141k', '160k', '144k', '143k', '190k', '376k', '193k',
#        '246k', '73k', '658k', '992k', '253k', '420k', '404k', '470k',
#        '226k', '240k', '89k', '234k', '257k', '861k', '467k', '157k',
#        '44k', '676k', '67k', '552k', '885k', '1020k', '582k', '619k'],
#       dtype=object)

# %%
df_copy['Size'] = df_copy['Size'].str.replace('M','000').str.replace('k','').str.replace('+','').replace('Varies with device',np.nan).astype(float)

# %%
df_copy['Size'].unique()
# Out:
# array([1.90e+04, 1.40e+04, 8.70e+00, 2.50e+04, 2.80e+00, 5.60e+00,
#        2.90e+04, 3.30e+04, 3.10e+00, 2.80e+04, 1.20e+04, 2.00e+04,
#        2.10e+04, 3.70e+04, 2.70e+00, 5.50e+00, 1.70e+04, 3.90e+04,
#        3.10e+04, 4.20e+00, 7.00e+00, 2.30e+04, 6.00e+00, 6.10e+00,
#        4.60e+00, 9.20e+00, 5.20e+00, 1.10e+04, 2.40e+04,      nan,
#        9.40e+00, 1.50e+04, 1.00e+04, 1.20e+00, 2.60e+04, 8.00e+00,
#        7.90e+00, 5.60e+04, 5.70e+04, 3.50e+04, 5.40e+04, 2.01e+02,
#        3.60e+00, 5.70e+00, 8.60e+00, 2.40e+00, 2.70e+04, 2.50e+00,
#        1.60e+04, 3.40e+00, 8.90e+00, 3.90e+00, 2.90e+00, 3.80e+04,
#        3.20e+04, 5.40e+00, 1.80e+04, 1.10e+00, 2.20e+00, 4.50e+00,
#        9.80e+00, 5.20e+04, 9.00e+00, 6.70e+00, 3.00e+04, 2.60e+00,
#        7.10e+00, 3.70e+00, 2.20e+04, 7.40e+00, 6.40e+00, 3.20e+00,
#        8.20e+00, 9.90e+00, 4.90e+00, 9.50e+00, 5.00e+00, 5.90e+00,
#        1.30e+04, 7.30e+04, 6.80e+00, 3.50e+00, 4.00e+00, 2.30e+00,
#        7.20e+00, 2.10e+00, 4.20e+04, 7.30e+00, 9.10e+00, 5.50e+04,
#        2.30e+01, 6.50e+00, 1.50e+00, 7.50e+00, 5.10e+04, 4.10e+04,
#        4.80e+04, 8.50e+00, 4.60e+04, 8.30e+00, 4.30e+00, 4.70e+00,
#        3.30e+00, 4.00e+04, 7.80e+00, 8.80e+00, 6.60e+00, 5.10e+00,
#        6.10e+04, 6.60e+04, 7.90e+01, 8.40e+00, 1.18e+02, 4.40e+04,
#        6.95e+02, 1.60e+00, 6.20e+00, 1.80e+01, 5.30e+04, 1.40e+00,
#        3.00e+00, 5.80e+00, 3.80e+00, 9.60e+00, 4.50e+04, 6.30e+04,
#        4.90e+04, 7.70e+04, 4.40e+00, 4.80e+00, 7.00e+04, 6.90e+00,
#        9.30e+00, 1.00e+01, 8.10e+00, 3.60e+04, 8.40e+04, 9.70e+04,
#        2.00e+00, 1.90e+00, 1.80e+00, 5.30e+00, 4.70e+04, 5.56e+02,
#        5.26e+02, 7.60e+04, 7.60e+00, 5.90e+04, 9.70e+00, 7.80e+04,
#        7.20e+04, 4.30e+04, 7.70e+00, 6.30e+00, 3.34e+02, 3.40e+04,
#        9.30e+04, 6.50e+04, 7.90e+04, 1.00e+05, 5.80e+04, 5.00e+04,
#        6.80e+04, 6.40e+04, 6.70e+04, 6.00e+04, 9.40e+04, 2.32e+02,
#        9.90e+04, 6.24e+02, 9.50e+04, 4.10e+01, 2.92e+02, 1.10e+01,
#        8.00e+04, 1.70e+00, 7.40e+04, 6.20e+04, 6.90e+04, 7.50e+04,
#        9.80e+04, 8.50e+04, 8.20e+04, 9.60e+04, 8.70e+04, 7.10e+04,
#        8.60e+04, 9.10e+04, 8.10e+04, 9.20e+04, 8.30e+04, 8.80e+04,
#        7.04e+02, 8.62e+02, 8.99e+02, 3.78e+02, 2.66e+02, 3.75e+02,
#        1.30e+00, 9.75e+02, 9.80e+02, 4.10e+00, 8.90e+04, 6.96e+02,
#        5.44e+02, 5.25e+02, 9.20e+02, 7.79e+02, 8.53e+02, 7.20e+02,
#        7.13e+02, 7.72e+02, 3.18e+02, 5.80e+01, 2.41e+02, 1.96e+02,
#        8.57e+02, 5.10e+01, 9.53e+02, 8.65e+02, 2.51e+02, 9.30e+02,
#        5.40e+02, 3.13e+02, 7.46e+02, 2.03e+02, 2.60e+01, 3.14e+02,
#        2.39e+02, 3.71e+02, 2.20e+02, 7.30e+02, 7.56e+02, 9.10e+01,
#        2.93e+02, 1.70e+01, 7.40e+01, 1.40e+01, 3.17e+02, 7.80e+01,
#        9.24e+02, 9.02e+02, 8.18e+02, 8.10e+01, 9.39e+02, 1.69e+02,
#        4.50e+01, 4.75e+02, 9.65e+02, 9.00e+04, 5.45e+02, 6.10e+01,
#        2.83e+02, 6.55e+02, 7.14e+02, 9.30e+01, 8.72e+02, 1.21e+02,
#        3.22e+02, 1.00e+00, 9.76e+02, 1.72e+02, 2.38e+02, 5.49e+02,
#        2.06e+02, 9.54e+02, 4.44e+02, 7.17e+02, 2.10e+02, 6.09e+02,
#        3.08e+02, 7.05e+02, 3.06e+02, 9.04e+02, 4.73e+02, 1.75e+02,
#        3.50e+02, 3.83e+02, 4.54e+02, 4.21e+02, 7.00e+01, 8.12e+02,
#        4.42e+02, 8.42e+02, 4.17e+02, 4.12e+02, 4.59e+02, 4.78e+02,
#        3.35e+02, 7.82e+02, 7.21e+02, 4.30e+02, 4.29e+02, 1.92e+02,
#        2.00e+02, 4.60e+02, 7.28e+02, 4.96e+02, 8.16e+02, 4.14e+02,
#        5.06e+02, 8.87e+02, 6.13e+02, 2.43e+02, 5.69e+02, 7.78e+02,
#        6.83e+02, 5.92e+02, 3.19e+02, 1.86e+02, 8.40e+02, 6.47e+02,
#        1.91e+02, 3.73e+02, 4.37e+02, 5.98e+02, 7.16e+02, 5.85e+02,
#        9.82e+02, 2.22e+02, 2.19e+02, 5.50e+01, 9.48e+02, 3.23e+02,
#        6.91e+02, 5.11e+02, 9.51e+02, 9.63e+02, 2.50e+01, 5.54e+02,
#        3.51e+02, 2.70e+01, 8.20e+01, 2.08e+02, 9.13e+02, 5.14e+02,
#        5.51e+02, 2.90e+01, 1.03e+02, 8.98e+02, 7.43e+02, 1.16e+02,
#        1.53e+02, 2.09e+02, 3.53e+02, 4.99e+02, 1.73e+02, 5.97e+02,
#        8.09e+02, 1.22e+02, 4.11e+02, 4.00e+02, 8.01e+02, 7.87e+02,
#        2.37e+02, 5.00e+01, 6.43e+02, 9.86e+02, 9.70e+01, 5.16e+02,
#        8.37e+02, 7.80e+02, 9.61e+02, 2.69e+02, 2.00e+01, 4.98e+02,
#        6.00e+02, 7.49e+02, 6.42e+02, 8.81e+02, 7.20e+01, 6.56e+02,
#        6.01e+02, 2.21e+02, 2.28e+02, 1.08e+02, 9.40e+02, 1.76e+02,
#        3.30e+01, 6.63e+02, 3.40e+01, 9.42e+02, 2.59e+02, 1.64e+02,
#        4.58e+02, 2.45e+02, 6.29e+02, 2.80e+01, 2.88e+02, 7.75e+02,
#        7.85e+02, 6.36e+02, 9.16e+02, 9.94e+02, 3.09e+02, 4.85e+02,
#        9.14e+02, 9.03e+02, 6.08e+02, 5.00e+02, 5.40e+01, 5.62e+02,
#        8.47e+02, 9.57e+02, 6.88e+02, 8.11e+02, 2.70e+02, 4.80e+01,
#        3.29e+02, 5.23e+02, 9.21e+02, 8.74e+02, 9.81e+02, 7.84e+02,
#        2.80e+02, 2.40e+01, 5.18e+02, 7.54e+02, 8.92e+02, 1.54e+02,
#        8.60e+02, 3.64e+02, 3.87e+02, 6.26e+02, 1.61e+02, 8.79e+02,
#        3.90e+01, 9.70e+02, 1.70e+02, 1.41e+02, 1.60e+02, 1.44e+02,
#        1.43e+02, 1.90e+02, 3.76e+02, 1.93e+02, 2.46e+02, 7.30e+01,
#        6.58e+02, 9.92e+02, 2.53e+02, 4.20e+02, 4.04e+02, 4.70e+02,
#        2.26e+02, 2.40e+02, 8.90e+01, 2.34e+02, 2.57e+02, 8.61e+02,
#        4.67e+02, 1.57e+02, 4.40e+01, 6.76e+02, 6.70e+01, 5.52e+02,
#        8.85e+02, 1.02e+03, 5.82e+02, 6.19e+02])

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  object
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 1.2+ MB

# %%
df_copy['Size']
# Out:
# 0        19000.0
# 1        14000.0
# 2            8.7
# 3        25000.0
# 4            2.8
#           ...
# 10836    53000.0
# 10837        3.6
# 10838        9.5
# 10839        NaN
# 10840    19000.0
# Name: Size, Length: 10840, dtype: float64

# %%
df['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0', 'Free'], dtype=object)

# %%
df['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
#        '$394.99', '$1.26', 'Everyone', '$1.20', '$1.04'], dtype=object)

# %%
chars_to_remove=['+','$',',']
cols_to_clean=['Installs','Price']
for item in chars_to_remove:
    for col in cols_to_clean:
        df_copy[col]=df_copy[col].str.replace(item,'')

# %%
df_copy['Installs'].unique()
# Out:
# array(['10000', '500000', '5000000', '50000000', '100000', '50000',
#        '1000000', '10000000', '5000', '100000000', '1000000000', '1000',
#        '500000000', '50', '100', '500', '10', '1', '5', '0'], dtype=object)

# %%
df_copy['Price'].unique()
# Out:
# array(['0', '4.99', '3.99', '6.99', '1.49', '2.99', '7.99', '5.99',
#        '3.49', '1.99', '9.99', '7.49', '0.99', '9.00', '5.49', '10.00',
#        '24.99', '11.99', '79.99', '16.99', '14.99', '1.00', '29.99',
#        '12.99', '2.49', '10.99', '1.50', '19.99', '15.99', '33.99',
#        '74.99', '39.99', '3.95', '4.49', '1.70', '8.99', '2.00', '3.88',
#        '25.99', '399.99', '17.99', '400.00', '3.02', '1.76', '4.84',
#        '4.77', '1.61', '2.50', '1.59', '6.49', '1.29', '5.00', '13.99',
#        '299.99', '379.99', '37.99', '18.99', '389.99', '19.90', '8.49',
#        '1.75', '14.00', '4.85', '46.99', '109.99', '154.99', '3.08',
#        '2.59', '4.80', '1.96', '19.40', '3.90', '4.59', '15.46', '3.04',
#        '4.29', '2.60', '3.28', '4.60', '28.99', '2.95', '2.90', '1.97',
#        '200.00', '89.99', '2.56', '30.99', '3.61', '394.99', '1.26',
#        '1.20', '1.04'], dtype=object)

# %%
df_copy['Installs']=df_copy['Installs'].astype(int)

# %%
df_copy['Price']=df_copy['Price'].astype(float)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1.2+ MB

# %%
df_copy.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
df_copy['Last Updated'].unique()
# Out:
# array(['January 7, 2018', 'January 15, 2018', 'August 1, 2018', ...,
#        'January 20, 2014', 'February 16, 2014', 'March 23, 2014'],
#       shape=(1377,), dtype=object)

# %%
df_copy['Last Updated']=pd.to_datetime(df_copy['Last Updated'])
df_copy['Day']=df_copy['Last Updated'].dt.day
df_copy['Month']=df_copy['Last Updated'].dt.month
df_copy['Year']=df_copy['Last Updated'].dt.year

# %%
df_copy.drop('Last Updated',axis=1,inplace=True)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Current Ver     10832 non-null  object
#  11  Android Ver     10838 non-null  object
#  12  Day             10840 non-null  int32
#  13  Month           10840 non-null  int32
#  14  Year            10840 non-null  int32
# dtypes: float64(3), int32(3), int64(2), object(7)
# memory usage: 1.2+ MB

# %%
df_copy.to_csv('cleaned_googleplaystore.csv',index=False)

# %%
df_copy['Rating'].unique()
# Out:
# array([4.1, 3.9, 4.7, 4.5, 4.3, 4.4, 3.8, 4.2, 4.6, 3.2, 4. , nan, 4.8,
#        4.9, 3.6, 3.7, 3.3, 3.4, 3.5, 3.1, 5. , 2.6, 3. , 1.9, 2.5, 2.8,
#        2.7, 1. , 2.9, 2.3, 2.2, 1.7, 2. , 1.8, 2.4, 1.6, 2.1, 1.4, 1.5,
#        1.2])

# %% [markdown]
# ### EDA

# %%
df_copy[df_copy.duplicated('App')]
# Out:
#                                       App       Category  Rating  Reviews  \
# 229          Quick PDF Scanner + OCR FREE       BUSINESS     4.2    80805
# 236                                   Box       BUSINESS     4.2   159872
# 239                    Google My Business       BUSINESS     4.4    70991
# 256                   ZOOM Cloud Meetings       BUSINESS     4.4    31614
# 261             join.me - Simple Meetings       BUSINESS     4.0     6989
# ...                                   ...            ...     ...      ...
# 10715                  FarmersOnly Dating         DATING     3.0     1145
# 10720  Firefox Focus: The privacy browser  COMMUNICATION     4.4    36981
# 10730                         FP Notebook        MEDICAL     4.5      410
# 10753      Slickdeals: Coupons & Shopping       SHOPPING     4.5    33599
# 10768                                AAFP        MEDICAL     3.8       63
#
#           Size  Installs  Type  Price Content Rating         Genres  \
# 229        NaN   5000000  Free    0.0       Everyone       Business
# 236        NaN  10000000  Free    0.0       Everyone       Business
# 239        NaN   5000000  Free    0.0       Everyone       Business
# 256    37000.0  10000000  Free    0.0       Everyone       Business
# 261        NaN   1000000  Free    0.0       Everyone       Business
# ...        ...       ...   ...    ...            ...            ...
# 10715      1.4    100000  Free    0.0     Mature 17+         Dating
# 10720      4.0   1000000  Free    0.0       Everyone  Communication
# 10730  60000.0     50000  Free    0.0       Everyone        Medical
# 10753  12000.0   1000000  Free    0.0       Everyone       Shopping
# 10768  24000.0     10000  Free    0.0       Everyone        Medical
#
#               Current Ver         Android Ver  Day  Month  Year
# 229    Varies with device        4.0.3 and up   26      2  2018
# 236    Varies with device  Varies with device   31      7  2018
# 239      2.19.0.204537701          4.4 and up   24      7  2018
# 256        4.1.28165.0716          4.0 and up   20      7  2018
# 261             4.3.0.508          4.4 and up   16      7  2018
# ...                   ...                 ...  ...    ...   ...
# 10715                 2.2          4.0 and up   25      2  2016
# 10720                 5.2          5.0 and up    6      7  2018
# 10730           2.1.0.372          4.4 and up   24      3  2018
# 10753                 3.9          4.4 and up   30      7  2018
# 10768               2.3.1          5.0 and up   22      6  2018
#
# [1181 rows x 15 columns]

# %% [markdown]
# > The dataset has `duplicate records`

# %%
df_copy.drop_duplicates(subset='App',keep='first',inplace=True)

# %%
df_copy.shape
# Out:
# (9659, 15)

# %% [markdown]
# ### **Explore Data**

# %%
numeric_features = [feature for feature in df_copy.columns if df_copy[feature].dtype != 'O']
categorical_features = [feature for feature in df_copy.columns if df_copy[feature].dtype == 'O']

#print columns with numeric data type
print('We have {} numerical features : {}'.format(len(numeric_features),numeric_features))
print('\nWe have {} categorical features : {}'.format(len(categorical_features),categorical_features))
# Out:
# We have 8 numerical features : ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'Day', 'Month', 'Year']
#
# We have 7 categorical features : ['App', 'Category', 'Type', 'Content Rating', 'Genres', 'Current Ver', 'Android Ver']

# %% [markdown]
# ### **Feature Information**
# > 1. **App** - Name of the App
# > 2. **Category** - Category of the App
# > 3. **Rating** - Average user rating of the app (out of 5)
# > 4. **Reviews** - Number of user reviews for the app
# > 5. **Size** - Size of the app (in MB or KB)
# > 6. **Installs** - Number of times the app has been installed
# > 7. **Type** - Whether the app is Free or Paid
# > 8. **Price** - Price of the app (in USD)
# > 9. **Content Rating** - Age group for which the app is suitable
# > 10. **Genres** - Genre(s) of the app
# > 11. **Last Updated** - Date when the app was last updated
# > 12. **Current Ver** - Current version of the app
# > 13. **Android Ver** - Minimum Android version required to run the app

# %%
## Proportion of count data on categorical columns
for feature in categorical_features:
    print(df[feature].value_counts(normalize=True)*100)
    print('\n')
# Out:
# App
# ROBLOX                                                0.083018
# CBS Sports App - Scores, News, Stats & Watch Live     0.073794
# ESPN                                                  0.064570
# Duolingo: Learn Languages Free                        0.064570
# Candy Crush Saga                                      0.064570
#                                                         ...
# Meet U - Get Friends for Snapchat, Kik & Instagram    0.009224
# U-Report                                              0.009224
# U of I Community Credit Union                         0.009224
# Waiting For U Launcher Theme                          0.009224
# iHoroscope - 2018 Daily Horoscope & Astrology         0.009224
# Name: proportion, Length: 9660, dtype: float64
#
#
# Category
# FAMILY                 18.190204
# GAME                   10.552532
# TOOLS                   7.776035
# MEDICAL                 4.270824
# BUSINESS                4.243151
# PRODUCTIVITY            3.911078
# PERSONALIZATION         3.615903
# COMMUNICATION           3.569781
# SPORTS                  3.542109
# LIFESTYLE               3.523660
# FINANCE                 3.376072
# HEALTH_AND_FITNESS      3.145466
# PHOTOGRAPHY             3.090121
# SOCIAL                  2.721151
# NEWS_AND_MAGAZINES      2.610460
# SHOPPING                2.398303
# TRAVEL_AND_LOCAL        2.379854
# DATING                  2.158472
# BOOKS_AND_REFERENCE     2.130800
# VIDEO_PLAYERS           1.614242
# EDUCATION               1.438982
# ENTERTAINMENT           1.374412
# MAPS_AND_NAVIGATION     1.263721
# FOOD_AND_DRINK          1.171479
# HOUSE_AND_HOME          0.811733
# LIBRARIES_AND_DEMO      0.784061
# AUTO_AND_VEHICLES       0.784061
# WEATHER                 0.756388
# ART_AND_DESIGN          0.599576
# EVENTS                  0.590351
# PARENTING               0.553454
# COMICS                  0.553454
# BEAUTY                  0.488885
# 1.9                     0.009224
# Name: proportion, dtype: float64
#
#
# Type
# Free    92.610701
# Paid     7.380074
# 0        0.009225
# Name: proportion, dtype: float64
#
#
# Content Rating
# Everyone           80.387454
# Teen               11.143911
# Mature 17+          4.603321
# Everyone 10+        3.819188
# Adults only 18+     0.027675
# Unrated             0.018450
# Name: proportion, dtype: float64
#
#
# Genres
# Tools                     7.766811
# Entertainment             5.746702
# Education                 5.064108
# Medical                   4.270824
# Business                  4.243151
#                             ...
# Arcade;Pretend Play       0.009224
# Card;Brain Games          0.009224
# Lifestyle;Pretend Play    0.009224
# Comics;Creativity         0.009224
# Strategy;Creativity       0.009224
# Name: proportion, Length: 120, dtype: float64
#
#
# Current Ver
# Varies with device    13.468107
# 1.0                    7.467922
# 1.1                    2.436998
# 1.2                    1.643127
# 2.0                    1.393889
#                         ...
# 1.0.17.3905            0.009231
# 15.1.2                 0.009231
# 4.94.19                0.009231
# 1.1.11.11              0.009231
# 2.0.148.0              0.009231
# Name: proportion, Length: 2832, dtype: float64
#
#
# Android Ver
# 4.1 and up            22.614874
# 4.0.3 and up          13.849419
# 4.0 and up            12.686843
# Varies with device    12.566894
# 4.4 and up             9.042259
# 2.3 and up             6.015870
# 5.0 and up             5.545304
# 4.2 and up             3.635357
# 2.3.3 and up           2.592729
# 2.2 and up             2.251338
# 4.3 and up             2.242111
# 3.0 and up             2.223658
# 2.1 and up             1.236390
# 1.6 and up             1.070308
# 6.0 and up             0.553608
# 7.0 and up             0.387525
# 3.2 and up             0.332165
# 2.0 and up             0.295257
# 5.1 and up             0.221443
# 1.5 and up             0.184536
# 4.4W and up            0.110722
# 3.1 and up             0.092268
# 2.0.1 and up           0.064588
# 8.0 and up             0.055361
# 7.1 and up             0.027680
# 4.0.3 - 7.1.1          0.018454
# 5.0 - 8.0              0.018454
# 1.0 and up             0.018454
# 7.0 - 7.1.1            0.009227
# 4.1 - 7.1.1            0.009227
# 5.0 - 6.0              0.009227
# 2.2 - 7.1.1            0.009227
# 5.0 - 7.1.1            0.009227
# Name: proportion, dtype: float64

# %%
## Proportion of count data on numerical columns
plt.figure(figsize=(15,10))
plt.suptitle('Univariate Analysis of Numerical features',fontsize=20,fontweight='bold',alpha=0.8,y=1.05)

for i in range(0,len(numeric_features)):
    plt.subplot(5,3,i+1)
    sns.kdeplot(x=df_copy[numeric_features[i]],shade=True,color='r')
    plt.xlabel(numeric_features[i])
    plt.tight_layout()
plt.show()

# %% [markdown]
# ### *Observations*
# > 1. `Rating` & `Year` are Left Skewed.
# > 2. `Reviews`, `Installs`, `Price` & `Size` are Right skewed.

# %%
## Proportion of count data on categorical columns
plt.figure(figsize=(18,20))
plt.suptitle('Univariate Analysis of Categorical features',fontsize=20,fontweight='bold',alpha=0.8,y=1.05)
category=['Category','Type','Content Rating','Genres']
for i in range(0,len(category)):
    plt.subplot(4,1,i+1)
    sns.countplot(x=df_copy[category[i]],palette="Set2")
    plt.xlabel(category[i])
    plt.xticks(rotation=90)
    plt.tight_layout()
plt.show()

# %%
df_copy['Category'].value_counts().plot.pie(y=df_copy['Category'],figsize=(15,15),autopct='%1.1f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### Observations
# > 1. Family,Tools and Game category are more in Playstore
# > 2. Beauty, Comics, Art and Design are less in Playstore

# %%
## Top 10 App categories
category = pd.DataFrame(df_copy['Category'].value_counts())
category.rename(columns={'category':'Count'},inplace=True)

# %%
category.head(10)
# Out:
#                  count
# Category
# FAMILY            1832
# GAME               959
# TOOLS              827
# BUSINESS           420
# MEDICAL            395
# PERSONALIZATION    376
# PRODUCTIVITY       374
# LIFESTYLE          369
# FINANCE            345
# SPORTS             325

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=category.index[:10],y='count',data=category[:10],palette='hls')
plt.title("Top 10 App categories")
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# ### Insights
# 1. Family category has the most number of apps with 18% of apps belonging to it, followed by Games category which has 11% of the apps.
# 2. Least number of apps belong to  the Beauty category with less than 1% of the total apps belonging to it.

# %%
df_copy.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
#
#                       Genres Current Ver   Android Ver  Day  Month  Year
# 0               Art & Design       1.0.0  4.0.3 and up    7      1  2018
# 1  Art & Design;Pretend Play       2.0.0  4.0.3 and up   15      1  2018

# %%
## Apps having rating > 5
df_copy[df_copy['Rating']>=5.0]
# Out:
#                                               App   Category  Rating  Reviews  \
# 329                  Hojiboy Tojiboyev Life Hacks     COMICS     5.0       15
# 612                 American Girls Mobile Numbers     DATING     5.0        5
# 615                                  Awake Dating     DATING     5.0        2
# 633                         Spine- The dating app     DATING     5.0        5
# 636    Girls Live Talk - Free Text and Video Chat     DATING     5.0        6
# ...                                           ...        ...     ...      ...
# 10721                           Mad Dash Fo' Cash       GAME     5.0       14
# 10742                       GKPB FP Online Church  LIFESTYLE     5.0       32
# 10776                            Monster Ride Pro       GAME     5.0        1
# 10820                             Fr. Daoud Lamei     FAMILY     5.0       22
# 10837            Fr. Mike Schmitz Audio Teachings     FAMILY     5.0        4
#
#           Size  Installs  Type  Price Content Rating     Genres Current Ver  \
# 329    37000.0      1000  Free    0.0       Everyone     Comics         2.0
# 612        4.4      1000  Free    0.0     Mature 17+     Dating         3.0
# 615    70000.0       100  Free    0.0     Mature 17+     Dating       2.2.9
# 633        9.3       500  Free    0.0           Teen     Dating         4.0
# 636        5.0       100  Free    0.0     Mature 17+     Dating         8.2
# ...        ...       ...   ...    ...            ...        ...         ...
# 10721  16000.0       100  Free    0.0       Everyone     Arcade        2.5a
# 10742      7.9      1000  Free    0.0       Everyone  Lifestyle       0.7.1
# 10776  24000.0        10  Free    0.0       Everyone     Racing         2.0
# 10820      8.6      1000  Free    0.0           Teen  Education       3.8.0
# 10837      3.6       100  Free    0.0       Everyone  Education         1.0
#
#         Android Ver  Day  Month  Year
# 329    4.0.3 and up   26      6  2018
# 612    4.0.3 and up   17      7  2018
# 615      4.4 and up   24      7  2018
# 633    4.0.3 and up   14      7  2018
# 636    4.0.3 and up    1      8  2018
# ...             ...  ...    ...   ...
# 10721    4.1 and up   19      6  2017
# 10742    4.4 and up   31     12  2017
# 10776    2.3 and up    5      3  2018
# 10820    4.1 and up   27      6  2018
# 10837    4.1 and up    6      7  2018
#
# [271 rows x 15 columns]

# %%
Category=df_copy['Category'].unique()
Category
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION'],
#       dtype=object)

# %%
for cat in Category:
    top5 = df_copy[df_copy['Category']==cat].sort_values(by='Installs',ascending=False).head(5)
    
    print(f'\nTop 5 apps in {cat}:')
    print(top5[['App','Installs']])
# Out:
# Top 5 apps in ART_AND_DESIGN:
#                                                   App  Installs
# 3                               Sketch - Draw & Paint  50000000
# 42                         Textgram - write on photos  10000000
# 45  Canva: Poster, banner, card maker & graphic de...  10000000
# 19                                       ibis Paint X  10000000
# 12                     Tattoo Name On My Photo Editor  10000000
#
# Top 5 apps in AUTO_AND_VEHICLES:
#                                                     App  Installs
# 8289                      AutoScout24 - used car finder  10000000
# 72        Android Auto - Maps, Media, Messaging & Voice  10000000
# 70    Fines of the State Traffic Safety Inspectorate...   5000000
# 69                          Used cars for sale - Trovit   5000000
# 67                                   Ulysse Speedometer   5000000
#
# Top 5 apps in BEAUTY:
#                                  App  Installs
# 117    Beauty Camera - Selfie Camera  10000000
# 7021    Best Hairstyles step by step   5000000
# 136                   Rainbow Camera   1000000
# 102       Mirror - Zoom & Exposure -   1000000
# 99    ipsy: Makeup, Beauty, and Tips   1000000
#
# Top 5 apps in BOOKS_AND_REFERENCE:
#                           App    Installs
# 152         Google Play Books  1000000000
# 139      Wattpad 📖 Free Books   100000000
# 143             Amazon Kindle   100000000
# 3941                    Bible   100000000
# 5651  Audiobooks from Audible   100000000
#
# Top 5 apps in BUSINESS:
#                                                      App   Installs
# 10253             File Commander - File Manager/Explorer  100000000
# 194               OfficeSuite : Free Office + PDF Editor  100000000
# 188                                    Indeed Job Search   50000000
# 192                        Docs To Go™ Free Office Suite   50000000
# 4683   Vault-Hide SMS,Pics & Videos,App Lock,Cloud ba...   50000000
#
# Top 5 apps in COMICS:
#                                                     App  Installs
# 297                          LINE WEBTOON - Free Comics  10000000
# 311   comico Popular Original Cartoon Updated Everyd...   5000000
# 330                                      Perfect Viewer   5000000
# 320                                    Narrator's Voice   5000000
# 8257                                             Comics   5000000
#
# Top 5 apps in COMMUNICATION:
#                                           App    Installs
# 335  Messenger – Text and Video Chat for Free  1000000000
# 391             Skype - free IM & video calls  1000000000
# 336                        WhatsApp Messenger  1000000000
# 338              Google Chrome: Fast & Secure  1000000000
# 340                                     Gmail  1000000000
#
# Top 5 apps in DATING:
#                                          App  Installs
# 591             Hitwe - meet people and chat  10000000
# 489                 Moco - Chat, Meet People  10000000
# 532       Chat Rooms, Avatars, Date - Galaxy  10000000
# 502  Find Real Love — YouLove Premium Dating  10000000
# 482           Zoosk Dating App: Meet Singles  10000000
#
# Top 5 apps in EDUCATION:
#                                                    App   Installs
# 699                     Duolingo: Learn Languages Free  100000000
# 825                                          ClassDojo   10000000
# 718                                        Math Tricks   10000000
# 717                           Babbel – Learn Languages   10000000
# 734  Lumosity: #1 Brain Games & Cognitive Training App   10000000
#
# Top 5 apps in ENTERTAINMENT:
#                      App    Installs
# 865    Google Play Games  1000000000
# 855              Netflix   100000000
# 888     IMDb Movies & TV   100000000
# 893  Talking Ben the Dog   100000000
# 874       Talking Angela   100000000
#
# Top 5 apps in EVENTS:
#                                                    App  Installs
# 1008    StubHub - Tickets to Sports, Concerts & Events   5000000
# 1005                        Ticketmaster Event Tickets   5000000
# 1009                                             Fever   1000000
# 1011  SeatGeek – Tickets to Sports, Concerts, Broadway   1000000
# 1014                       Vivid Seats – Event Tickets   1000000
#
# Top 5 apps in FINANCE:
#                      App   Installs
# 1083          Google Pay  100000000
# 1076              PayPal   50000000
# 1048              K PLUS   10000000
# 1059           Itau bank   10000000
# 1073  Wells Fargo Mobile   10000000
#
# Top 5 apps in FOOD_AND_DRINK:
#                                  App  Installs
# 1176                      McDonald's  10000000
# 1250  Uber Eats: Local Food Delivery  10000000
# 1231                         Cookpad  10000000
# 1199              Domino's Pizza USA  10000000
# 1236           Foursquare City Guide  10000000
#
# Top 5 apps in HEALTH_AND_FITNESS:
#                                                     App   Installs
# 5596                                     Samsung Health  500000000
# 1360  Period Tracker - Period Calendar Ovulation Tra...  100000000
# 1286                     Calorie Counter - MyFitnessPal   50000000
# 1305                     Workout Trainer: fitness coach   10000000
# 1289                      Endomondo - Running & Walking   10000000
#
# Top 5 apps in HOUSE_AND_HOME:
#                                                     App  Installs
# 1446  Zillow: Find Houses for Sale & Apartments for ...  10000000
# 1454                       Trulia Real Estate & Rentals  10000000
# 1449   Realtor.com Real Estate: Homes for Sale and Rent  10000000
# 4205                               tinyCam Monitor FREE  10000000
# 1456                        Houzz Interior Design Ideas  10000000
#
# Top 5 apps in LIBRARIES_AND_DEMO:
#                               App  Installs
# 10729     MX Player Codec (ARMv7)  10000000
# 1535                    Cardboard  10000000
# 1523   Aviary Stickers: Free Pack  10000000
# 1521      Aviary Effects: Classic   5000000
# 1542         Wifi Connect Library   5000000
#
# Top 5 apps in LIFESTYLE:
#                                                  App   Installs
# 4587                                          Tinder  100000000
# 1584                                        Samsung+   50000000
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology   10000000
# 1577                    Family Locator - GPS Tracker   10000000
# 1600                  OK cashbag [point of pleasure]   10000000
#
# Top 5 apps in GAME:
#                    App    Installs
# 1654    Subway Surfers  1000000000
# 1655  Candy Crush Saga   500000000
# 1661      Temple Run 2   500000000
# 1662               Pou   500000000
# 1722    My Talking Tom   500000000
#
# Top 5 apps in FAMILY:
#                                 App   Installs
# 6269  Bitmoji – Your Personal Emoji  100000000
# 4229         Where's My Water? Free  100000000
# 4111              Talking Tom Cat 2  100000000
# 6849            Bubble Witch 2 Saga  100000000
# 4329               Tom Loves Angela  100000000
#
# Top 5 apps in MEDICAL:
#                                                 App  Installs
# 2310                                 Blood Pressure   5000000
# 2319                   My Calendar - Period Tracker   5000000
# 2303                 GoodRx Drug Prices and Coupons   1000000
# 2316  Ovia Fertility Tracker & Ovulation Calculator   1000000
# 2330                        Ada - Your Health Guide   1000000
#
# Top 5 apps in SOCIAL:
#                 App    Installs
# 2544       Facebook  1000000000
# 2554        Google+  1000000000
# 2545      Instagram  1000000000
# 2546  Facebook Lite   500000000
# 2550       Snapchat   500000000
#
# Top 5 apps in SHOPPING:
#                                                     App   Installs
# 2664                                    Amazon Shopping  100000000
# 2662  eBay: Buy & Sell this Summer - Discover Deals ...  100000000
# 2698                       Flipkart Online Shopping App  100000000
# 2655                           Wish - Shopping Made Fun  100000000
# 2660       AliExpress - Smarter Shopping, Better Living  100000000
#
# Top 5 apps in PHOTOGRAPHY:
#                                          App    Installs
# 2808                           Google Photos  1000000000
# 2897                        Photo Editor Pro   100000000
# 2849    YouCam Perfect - Selfie Photo Editor   100000000
# 2869              LINE Camera - Photo editor   100000000
# 2833  YouCam Makeup - Magic Selfie Makeovers   100000000
#
# Top 5 apps in SPORTS:
#                                         App   Installs
# 8445                            FIFA Soccer  100000000
# 4054                             3D Bowling  100000000
# 5438                              3D Tennis   50000000
# 3084  Cricbuzz - Live Cricket Scores & News   50000000
# 2963                                    NFL   50000000
#
# Top 5 apps in TRAVEL_AND_LOCAL:
#                                                     App    Installs
# 3127                                 Google Street View  1000000000
# 3117                          Maps - Navigate & Explore  1000000000
# 3112                           Booking.com Travel Deals   100000000
# 3121                                       Google Earth   100000000
# 3115  TripAdvisor Hotels Flights Restaurants Attract...   100000000
#
# Top 5 apps in TOOLS:
#                                                     App    Installs
# 3234                                             Google  1000000000
# 3235                                   Google Translate   500000000
# 4005            Clean Master- Space Cleaner & Antivirus   500000000
# 7536  Security Master - Antivirus, VPN, AppLock, Boo...   500000000
# 3265                       Gboard - the Google Keyboard   500000000
#
# Top 5 apps in PERSONALIZATION:
#                                                    App   Installs
# 3446  GO Keyboard - Emoticon keyboard, Free Theme, GIF  100000000
# 4474     Parallel Space - Multiple accounts & Two face  100000000
# 3354                     ZEDGE™ Ringtones & Wallpapers  100000000
# 3425                       Backgrounds HD (Wallpapers)  100000000
# 3385                    Hola Launcher- Theme,Wallpaper  100000000
#
# Top 5 apps in PRODUCTIVITY:
#                   App    Installs
# 3454     Google Drive  1000000000
# 3450   Microsoft Word   500000000
# 3473          Dropbox   500000000
# 3574      Cloud Print   500000000
# 3476  Google Calendar   500000000
#
# Top 5 apps in PARENTING:
#                                                     App  Installs
# 7229     Pregnancy Tracker & Countdown to Baby Due Date  10000000
# 3576                                      My baby Piano   5000000
# 3605   Safe365 – Cell Phone GPS Locator For Your Family   1000000
# 3591                                      My baby Phone   1000000
# 3597  Family Album Mitene: Private Photo & Video Sha...   1000000
#
# Top 5 apps in WEATHER:
#                                                     App  Installs
# 3626  The Weather Channel: Rain Forecast & Storm Alerts  50000000
# 3628  AccuWeather: Daily Forecast & Live Weather Rep...  50000000
# 4725                 Weather & Clock Widget for Android  50000000
# 3649   GO Weather - Widget, Theme, Wallpaper, Efficient  50000000
# 3639                                      Yahoo Weather  10000000
#
# Top 5 apps in VIDEO_PLAYERS:
#                           App    Installs
# 3665                  YouTube  1000000000
# 3687  Google Play Movies & TV  1000000000
# 3703                MX Player   500000000
# 3672         Motorola Gallery   100000000
# 4032                 Dubsmash   100000000
#
# Top 5 apps in NEWS_AND_MAGAZINES:
#                                                     App    Installs
# 3736                                        Google News  1000000000
# 3755                       Flipboard: News For Our Time   500000000
# 3739                                            Twitter   500000000
# 3729   Dailyhunt (Newshunt) - Latest News, Viral Videos    50000000
# 3715  Fox News – Breaking News, Live Video & News Al...    10000000
#
# Top 5 apps in MAPS_AND_NAVIGATION:
#                                                     App   Installs
# 3820  Waze - GPS, Maps, Traffic Alerts & Live Naviga...  100000000
# 3827                                               Uber  100000000
# 3828                GPS Navigation & Offline Maps Sygic   50000000
# 6068                                Free GPS Navigation   50000000
# 3834                                            Compass   10000000
