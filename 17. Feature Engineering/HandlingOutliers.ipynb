# %% [markdown]
# ## **5 number Summary and Box Plot**

# %% [markdown]
# ### Minimum, Maximum, Median, Q1, Q3, IOR

# %%
import numpy as np 
lst_marks=[45,32,56,72,59,81,92,55,41,36,84,66,94,58,46,33,77]

# %%
Min,Q1,median,Q3,Max=np.quantile(lst_marks,[0,0.25,0.5,0.75,1.0])

# %%
Min,Q1,median,Q3,Max
# Out:
# (np.float64(32.0),
#  np.float64(45.0),
#  np.float64(58.0),
#  np.float64(77.0),
#  np.float64(94.0))

# %%
IQR=Q3-Q1
IQR
# Out:
# np.float64(32.0)

# %%
lower_fence=Q1-1.5*IQR
upper_fence=Q3+1.5*IQR
lower_fence,upper_fence
# Out:
# (np.float64(-3.0), np.float64(125.0))

# %%
lst_marks=[-57,45,32,56,72,-75,59,81,92,55,41,42,36,84,66,94,58,46,33,240,77]

# %%
## adding outliers 
import seaborn as sns
sns.boxplot(lst_marks)
# Out:
# <Axes: >
